# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/NorthwesternHeader.png?raw=1">

# %% [markdown]
# ## MSDS458 Research Assignment 2
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div><br>

# %% [markdown]
# The CIFAR-10 dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>The CIFAR-10 dataset</b><br>
# https://www.cs.toronto.edu/~kriz/cifar.html
#     </div>

# %% [markdown]
# ## Import packages needed

# %%
# Helper libraries
import datetime
from packaging import version
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.metrics import confusion_matrix
from collections import Counter
import numpy as np
import pandas as pd

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, Input, Dense

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ### Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.5.0

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.5.0

# %% [markdown]
# ### Mount Google Drive to Colab Enviorment

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ## Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.<br>
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# * Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
# * x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
# * y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)

# %% [markdown]
# ## EDA Training and Test Datasets
#
# * Imported 50000 examples for training and 10000 examples for test
# * Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(train_images.shape))
print('train_labels:\t{}'.format(train_labels.shape))
print('test_images:\t\t{}'.format(test_images.shape))
print('test_labels:\t\t{}'.format(test_labels.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# ### Review labels for training dataset

# %%
print("First ten labels training dataset:\n {}\n".format(train_labels[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# ### Plot Examples

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)
    
    x = x[indices]
    y = y[indices]
    
    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)
    
    x = x[indices]
    y = y[indices]
    
    y = tf.keras.utils.to_categorical(y)
    
    return x, y

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(x_train, y_train)
x_preview, y_preview = get_three_classes(x_test, y_test)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)
    
    x = x[indices]
    y = y[indices]
    p = p[indices]
    
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# ### Random Review of Examples

# %%
show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# ## Preprocessing Data for Model Development

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %% [markdown]
# ### Preprocessing the Examples
#  The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255.

# %% [markdown]
# 1. Each element in each example is a pixel value
# 2. Pixel values range from 0 to 255
# 3. 0 = black
# 4. 255 = white

# %%
train_images_norm = train_images.astype('float32')/255.
test_images_norm = test_images.astype('float32')/255.

# %%
train_images_norm.shape, test_images_norm.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %% [markdown]
# ## Validating our approach
#
# 10,000 samples of our training data to use as a validation set.

# %%
val_images_norm, train_images_norm = train_images_norm[:3000], train_images_norm[3000:] 
val_labels, train_labels = train_labels[:3000], train_labels[3000:]

# %%
val_images_norm.shape, val_labels.shape
# Out:
# ((3000, 32, 32, 3), (3000, 1))

# %%
train_images_norm.shape, train_labels.shape
# Out:
# ((47000, 32, 32, 3), (47000, 1))

# %% [markdown]
# ## Create the Model

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/CNN_architecture_v4.png?raw=1">

# %% [markdown]
# ### Build CNN Model

# %% [markdown]
# We use a Sequential class defined in Keras to create our model. The first 4 layers Conv2D and MaxPooling handle feature learning.  The last 3 layers, handle classification.

# %%
model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D((2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.L2(0.001)))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 256)       295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 384)               786816
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                3850
# =================================================================
# Total params: 2,269,578
# Trainable params: 2,269,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "CIFAR10.png", show_shapes=True)

# %% [markdown]
# ### Compiling the model

# %% [markdown]
# In addition to setting up our model architecture, we also need to define which algorithm should the model use in order to optimize the weights and biases as per the given data. We will use stochastic gradient descent.
#
# We also need to define a loss function. Think of this function as the difference between the predicted outputs and the actual outputs given in the dataset. This loss needs to be minimised in order to have a higher model accuracy. That's what the optimization algorithm essentially does - it minimises the loss during model training. For our multi-class classification problem, categorical cross entropy is commonly used.
#
# Finally, we will use the accuracy during training as a metric to keep track of as the model trains.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.losses.SparseCategoricalCrossentropy</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy</div>

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Module: tf.keras.callbacks</b></div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.callbacks.EarlyStopping</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.callbacks.ModelCheckpoint</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint</div>

# %%
history = model.fit(train_images_norm
                    ,train_labels
                    ,epochs=200
                    ,batch_size=512
                    ,validation_data=(val_images_norm,val_labels)
                    ,callbacks=[
                    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    tf.keras.callbacks.ModelCheckpoint('./models/model_{val_accuracy:.4f}.h5', save_best_only=True,
                                        save_weights_only=False, monitor='val_accuracy')]                                                                                                           
                   )
# Out:
# Epoch 1/200
# 92/92 [==============================] - 647s 7s/step - loss: 2.0765 - accuracy: 0.3157 - val_loss: 1.6470 - val_accuracy: 0.4443
# Epoch 2/200
# 92/92 [==============================] - 645s 7s/step - loss: 1.5101 - accuracy: 0.4846 - val_loss: 1.3232 - val_accuracy: 0.5810
# Epoch 3/200
# 92/92 [==============================] - 655s 7s/step - loss: 1.3102 - accuracy: 0.5596 - val_loss: 1.1621 - val_accuracy: 0.6223
# Epoch 4/200
# 92/92 [==============================] - 646s 7s/step - loss: 1.1866 - accuracy: 0.6070 - val_loss: 1.0745 - val_accuracy: 0.6637
# Epoch 5/200
# 92/92 [==============================] - 647s 7s/step - loss: 1.0979 - accuracy: 0.6401 - val_loss: 1.0353 - val_accuracy: 0.6520
# Epoch 6/200
# 92/92 [==============================] - 646s 7s/step - loss: 1.0353 - accuracy: 0.6624 - val_loss: 0.9410 - val_accuracy: 0.6953
# Epoch 7/200
# 92/92 [==============================] - 647s 7s/step - loss: 0.9727 - accuracy: 0.6824 - val_loss: 0.8988 - val_accuracy: 0.7197
# Epoch 8/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.9215 - accuracy: 0.7006 - val_loss: 0.8285 - val_accuracy: 0.7447
# Epoch 9/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.8766 - accuracy: 0.7185 - val_loss: 0.8279 - val_accuracy: 0.7473
# Epoch 10/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.8479 - accuracy: 0.7279 - val_loss: 0.7800 - val_accuracy: 0.7573
# Epoch 11/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.8058 - accuracy: 0.7435 - val_loss: 0.7559 - val_accuracy: 0.7600
# Epoch 12/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.7884 - accuracy: 0.7476 - val_loss: 0.7645 - val_accuracy: 0.7693
# Epoch 13/200
# 92/92 [==============================] - 645s 7s/step - loss: 0.7578 - accuracy: 0.7598 - val_loss: 0.7116 - val_accuracy: 0.7770
# Epoch 14/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.7379 - accuracy: 0.7671 - val_loss: 0.7132 - val_accuracy: 0.7730
# Epoch 15/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.7027 - accuracy: 0.7803 - val_loss: 0.7025 - val_accuracy: 0.7773
# Epoch 16/200
# 92/92 [==============================] - 647s 7s/step - loss: 0.6944 - accuracy: 0.7812 - val_loss: 0.6927 - val_accuracy: 0.7863
# Epoch 17/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.6777 - accuracy: 0.7887 - val_loss: 0.6736 - val_accuracy: 0.7997
# Epoch 18/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.6529 - accuracy: 0.7977 - val_loss: 0.7232 - val_accuracy: 0.7777
# Epoch 19/200
# 92/92 [==============================] - 647s 7s/step - loss: 0.6424 - accuracy: 0.8008 - val_loss: 0.6988 - val_accuracy: 0.7907
# Epoch 20/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.6219 - accuracy: 0.8096 - val_loss: 0.6672 - val_accuracy: 0.8000
# Epoch 21/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.6042 - accuracy: 0.8147 - val_loss: 0.6577 - val_accuracy: 0.8007
# Epoch 22/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.5973 - accuracy: 0.8173 - val_loss: 0.6599 - val_accuracy: 0.8003
# Epoch 23/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.5794 - accuracy: 0.8268 - val_loss: 0.6364 - val_accuracy: 0.8093
# Epoch 24/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.5645 - accuracy: 0.8311 - val_loss: 0.6544 - val_accuracy: 0.8007
# Epoch 25/200
# 92/92 [==============================] - 647s 7s/step - loss: 0.5560 - accuracy: 0.8306 - val_loss: 0.6238 - val_accuracy: 0.8193
# Epoch 26/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.5368 - accuracy: 0.8373 - val_loss: 0.6394 - val_accuracy: 0.8057
# Epoch 27/200
# 92/92 [==============================] - 646s 7s/step - loss: 0.5375 - accuracy: 0.8394 - val_loss: 0.6334 - val_accuracy: 0.8107
# Epoch 28/200
# 92/92 [==============================] - 647s 7s/step - loss: 0.5187 - accuracy: 0.8458 - val_loss: 0.6512 - val_accuracy: 0.8023

# %% [markdown]
# ### Validation Data
# Data on which to evaluate the loss and any model metrics at the end of each epoch<br>
# The model will not be trained on this data

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# In order to ensure that this is not a simple "memorization" by the machine, we should evaluate the performance on the test set. This is easy to do, we simply use the `evaluate` method on our model.

# %%
loss, accuracy = model.evaluate(test_images_norm, test_labels)
print('test set accuracy: ', accuracy * 100)
# Out:
# 313/313 [==============================] - 35s 111ms/step - loss: 0.7109 - accuracy: 0.7853
# test set accuracy:  78.53000164031982

# %% [markdown]
# ## Predictions

# %%
preds = model.predict(test_images_norm)
print('shape of preds: ', preds.shape)
# Out:
# shape of preds:  (10000, 10)

# %% [markdown]
# ## Plotting Performance Metrics
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#      loss  accuracy  val_loss  val_accuracy
# 23  0.565     0.831     0.654         0.801
# 24  0.556     0.831     0.624         0.819
# 25  0.537     0.837     0.639         0.806
# 26  0.537     0.839     0.633         0.811
# 27  0.519     0.846     0.651         0.802

# %%
losses = history.history['loss']
accs = history.history['accuracy']
val_losses = history.history['val_loss']
val_accs = history.history['val_accuracy']
epochs = len(losses)

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Confusion matrices
#
# Let us see what the confusion matrix looks like. Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %% [markdown]
# Get the predicted classes

# %%
pred_classes = np.argmax(model.predict(test_images_norm), axis=-1)

# %% [markdown]
# ### Visualizing the confusion matrix

# %%
conf_mx = tf.math.confusion_matrix(test_labels, pred_classes)
conf_mx
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[801,  13,  44,  10,  13,   7,   6,  12,  64,  30],
#        [  6, 891,   8,   4,   1,   3,   3,   4,  19,  61],
#        [ 40,   3, 721,  18,  59,  83,  31,  24,  12,   9],
#        [ 13,   4,  71, 447,  50, 317,  34,  33,  10,  21],
#        [ 16,   1,  54,  25, 758,  59,  19,  59,   7,   2],
#        [  9,   2,  38,  50,  29, 825,   5,  35,   2,   5],
#        [  1,   3,  61,  26,  39,  54, 798,   8,   3,   7],
#        [  9,   1,  23,  14,  31,  74,   0, 834,   5,   9],
#        [ 25,  15,  14,   5,   2,   9,   0,   7, 900,  23],
#        [ 15,  44,   9,   3,   2,   6,   5,   9,  29, 878]], dtype=int32)>

# %%
plt.figure(figsize=(16,8))
plt.matshow(conf_mx, cmap=plt.cm.Blues,fignum=1)
plt.xlabel("Predicted Classes")
plt.ylabel("Actual Classes")
plt.show()

# %% [markdown]
# ### Load HDF5 Model Format

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.models.load_model</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/models/load_model</div>

# %%
model = tf.keras.models.load_model('./models/model_0.8137.h5')

# %%
preds = model.predict(test_images_norm)

# %%
preds.shape
# Out:
# (10000, 10)

# %% [markdown]
# ### Predictions

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

# %%
df = pd.DataFrame(preds[0:20], columns = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
df.style.format("{:.2%}").background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row6_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row6_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row18_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row18_col1{
#             background-color:  #eff0f2;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row2_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row2_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row2_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row2_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row2_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row2_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row3_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row3_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row3_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row3_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row3_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row4_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row4_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row4_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row4_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row4_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row4_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row5_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row6_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row6_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row6_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row7_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row7_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row7_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row7_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row8_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row8_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row8_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row8_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row9_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row10_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row10_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row10_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row11_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row12_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row12_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row12_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row12_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row13_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row14_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row14_col1,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row14 ...
#             background-color:  #f0f1f2;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row12_col5{
#             background-color:  #8a9ce6;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col6,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row3_col9,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row6_col2,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row7_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row8_col6{
#             background-color:  #f0f0f2;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col5{
#             background-color:  #d6daef;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row0_col8,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row4_col3,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row8_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row15_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row16_col7,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row17_col6{
#             background-color:  #efeff2;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row2_col0,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row8_col4,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row10_col5,#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row17_col9{
#             background-color:  #edeef2;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col1{
#             background-color:  #adb9ea;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d0row1_col8{
#             background-color:  #b7c1eb;
#             color:  #000000;
#         }#T_ffa486b4_d1a7_11eb_8398_38b1db37c2d

# %%
(_,_), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

img = test_images[2004]
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

plt.imshow(img, cmap='viridis')
plt.axis('off')
plt.show()

# %%
# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[:8]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)
len(activations)
# Out:
# 8

# %%
layer_names = []
for layer in model.layers:
    layer_names.append(layer.name)
    
layer_names
# Out:
# ['conv2d',
#  'max_pooling2d',
#  'dropout',
#  'conv2d_1',
#  'max_pooling2d_1',
#  'dropout_1',
#  'conv2d_2',
#  'max_pooling2d_2',
#  'dropout_2',
#  'flatten',
#  'dense',
#  'dense_1']

# %%
# These are the names of the layers, so can have them as part of our plot
layer_names = []
for layer in model.layers[:3]:
    layer_names.append(layer.name)

images_per_row = 16

# Now let's display our feature maps
for layer_name, layer_activation in zip(layer_names, activations):
    # This is the number of features in the feature map
    n_features = layer_activation.shape[-1]

    # The feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # We will tile the activation channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # We'll tile each filter into this big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # Post-process the feature to make it visually palatable
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show();
